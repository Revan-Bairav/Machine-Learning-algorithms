# %% [markdown]
# <a href="https://colab.research.google.com/github/Revan-Bairav/Machine-Learning-algorithms/blob/main/PCA_vs_KernelPCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-learn matplotlib numpy
import matplotlib.pyplot as plt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from sklearn.datasets import load_iris
iris = load_iris()
X = iris.data
y = iris.target

# %%
from sklearn.decomposition import PCA, KernelPCA
# PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

# %%
# Kernel PCA
kpca = KernelPCA(n_components=2, kernel='rbf', gamma=15)
X_kpca = kpca.fit_transform(X)

# %%
plt.figure(figsize=(10, 5))

# %%
plt.subplot(1, 2, 1)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y, alpha=0.8)
plt.title('PCA')


plt.subplot(1, 2, 2)
plt.scatter(X_kpca[:, 0], X_kpca[:, 1], c=y, alpha=0.8)
plt.title('Kernel PCA')
plt.show()
